# %%
from src.utility import jsonl_reader
from src.inference import Inference

# %%
dataset = jsonl_reader('dataset/sample_dataset.jsonl')

# %%
sample = dataset[0]['document']

# %%
#sample prediction
Inference(sample).predict
# Out:
# /home/rita/projects/nirveda/src/inference.py:41: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([data, dataframe])
#     line_id  ... address_classifier
# 0         0  ...    non-addressline
# 1         1  ...    non-addressline
# 2         2  ...     vendor-address
# 3         3  ...     vendor-address
# 4         4  ...    non-addressline
# 5         5  ...    non-addressline
# 6         6  ...      buyer-address
# 7         7  ...      buyer-address
# 8         8  ...      buyer-address
# 9         9  ...      buyer-address
# 10       10  ...      buyer-address
# 11       11  ...    non-addressline
# 12       12  ...      buyer-address
# 13       13  ...      buyer-address
# 14       14  ...      buyer-address
# 0        15  ...    non-addressline
# 1        16  ...    non-addressline
# 2        17  ...    non-addressline
# 3        18  ...    non-addressline
# 4        19  ...    non-addressline
# 5        20  ...    non-addressline
# 6        21  ...    non-addressline
# 7        22  ...    non-addressline
# 8        23  ...    non-addressline
# 9        24  ...    non-addressline
# 10       25  ...    non-addressline
# 11       26  ...    non-addressline
# 12       27  ...    non-addressline
# 13       28  ...    non-addressline
# 14       29  ...    non-addressline
# 15       30  ...    non-addressline
# 16       31  ...    non-addressline
# 17       32  ...    non-addressline
# 18       33  ...    non-addressline
# 19       34  ...    non-addressline
# 20       35  ...    non-addressline
# 21       36  ...    non-addressline
# 22       37  ...    non-addressline
# 23       38  ...    non-addressline
#
# [39 rows x 4 columns]
